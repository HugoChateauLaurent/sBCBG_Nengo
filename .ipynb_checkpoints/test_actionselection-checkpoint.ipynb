# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from nengo_bg import sBCBG
import nengo
import nengo_ocl
from nengo.utils.matplotlib import rasterplot

# %%
model = nengo.Network(label='Basal Ganglia')
with model:
    basal_ganglia = sBCBG(dimensions=3, input_bias=0., output_weight=-1.)

    
timescale=1.

class ActionIterator(object):
    def __init__(self, dimensions):
        self.actions = np.ones(dimensions) * 0.

    def step(self, t):
        # one action at time dominates
        #print(t)
        dominate = int(t*timescale % 3)
        self.actions[:] = 2.
        self.actions[dominate] = 10000.
        return self.actions


action_iterator = ActionIterator(dimensions=3)

with model:
    actions = nengo.Node(action_iterator.step, label="actions")
    
    nengo.Connection(actions, basal_ganglia.input, synapse=None)
    selected_action = nengo.Probe(basal_ganglia.output)
    input_actions = nengo.Probe(actions)
    CSN = [nengo.Probe(basal_ganglia.pops['CSN'][d].neurons) for d in range(3)]
    MSN = [nengo.Probe(basal_ganglia.pops['MSN'][d].neurons) for d in range(3)]
    GPi = [nengo.Probe(basal_ganglia.pops['GPi'][d].neurons) for d in range(3)]
# Out:
# Command Line Parameters
# ['/usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py', '-f', '/run/user/1000/jupyter/kernel-754ae1e3-53cd-424e-b769-f235ca457621.json']
# ('Incorrect number of parameters:', 3, '-', 38, 'expected')
# ('/!\\ Using the following LG14 parameterization', 9)
# ### Parameterization #9 from (Lienard & Girard, 2014) is used. ###
# INFO: keeping LG14 value for theta in GPi to its original value of 6.2
# INFO: keeping LG14 value for theta in GPe to its original value of 10.5
# INFO: keeping LG14 value for theta in STN to its original value of 26.1
# INFO: keeping LG14 value for theta in Prot to its original value of 10.5
# INFO: keeping LG14 value for theta in MSN to its original value of 30.0
# INFO: keeping LG14 value for theta in Arky to its original value of 10.5
# INFO: keeping LG14 value for theta in FSI to its original value of 16.2
#
# Creating neurons
# ================
# 3
# ('* MSN:', 7932.0, 'neurons (divided in', 3, 'channels) with parameters:', {'tau_m': 13.0, 'C_m': 13.0, 'V_th': 30.0})
# 3
# ('* FSI:', 159.0, 'neurons (divided in', 3, 'channels) with parameters:', {'tau_m': 3.1, 'C_m': 3.1, 'V_th': 16.2})
# 3
# ('* STN:', 24.0, 'neurons (divided in', 3, 'channels) with parameters:', {'tau_m': 6.0, 'C_m': 6.0, 'V_th': 26.1})
# 3
# ('* GPe:', 75.0, 'neurons (divided in', 3, 'channels) with parameters:', {'tau_m': 14.0, 'C_m': 14.0, 'V_th': 10.5})
# 3
# ('* GPi:', 42.0, 'neurons (divided in', 3, 'channels) with parameters:', {'tau_m': 14.0, 'C_m': 14.0, 'V_th': 6.2})
# 3
# ('* CSN(fake):', 3000.0, 'Poisson generators with avg rate:', 2.0)
# TODONengo: seed and dt as parameters for Poisson generators
# TODONengo: seed and dt as parameters for Poisson generators
# TODONengo: seed and dt as parameters for Poisson generators
# 3
# ('* PTN(fake):', 100.0, 'Poisson generators with avg rate:', 15.0)
# TODONengo: seed and dt as parameters for Poisson generators
# TODONengo: seed and dt as parameters for Poisson generators
# TODONengo: seed and dt as parameters for Poisson generators
# 3
# ('* CMPf(fake):', 9.0, 'Poisson generators with avg rate:', 4.0)
# TODONengo: seed and dt as parameters for Poisson generators
# TODONengo: seed and dt as parameters for Poisson generators
# TODONengo: seed and dt as parameters for Poisson generators
# ('Number of simulated neurons:', {'MSN': 2644.0, 'CSN': 3000.0, 'Arky': 0.0, 'CMPf': 9.0, 'GPe': 25.0, 'FSI': 53.0, 'STN': 8.0, 'Prot': 0.0, 'PTN': 100.0, 'GPi': 14.0})
#
# Connecting neurons
# ================
# ('**', '', 'antagonist injection in', 'none', '**')
# * MSN Inputs
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "MSN ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "MSN ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "MSN ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "MSN ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "MSN ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "MSN ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "FSI ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "FSI ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "FSI ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "FSI ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "FSI ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "FSI ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "STN ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "STN ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "STN ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "STN ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "STN ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "STN ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "GPe ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "GPe ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "GPe ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "GPe ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "GPe ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "GPe ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "GPi ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "GPi ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "GPi ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "GPi ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "GPi ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'Ie' on '<Ensemble "GPi ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "CSN ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "CSN ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "CSN ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "PTN ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "PTN ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "PTN ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "CMPf ch0">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "CMPf ch1">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'efferents' on '<Ensemble "CMPf ch2">'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc85f3b5dd0> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc85f3b5f90> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a52190> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a52390> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a52550> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a52710> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a52890> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a52a50> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a52c10> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a52dd0> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a52f90> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a73190> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a73390> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a73550> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a73710> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a738d0> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a73a90> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a73c10> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a73e10> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a73fd0> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a901d0> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a90390> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a90550> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a90710> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a908d0> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a90a90> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a90c50> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a90e10> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc857a90fd0> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84881b1d0> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84881b390> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84881b550> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84881b710> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc869b43e90> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84881b9d0> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84881bb90> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84881bd50> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84881bf10> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84883c110> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84883c2d0> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84883c490> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84883c650> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84883c810> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84883c9d0> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84883cb90> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84883cd50> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc84883cf10> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487dc110> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487dc2d0> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487dc490> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487dc650> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487dc810> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487dc9d0> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487dcb90> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487dcd50> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487dce90> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487f9150> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487f9290> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487f94d0> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487f9690> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487f9850> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487f9a10> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487f9bd0> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487f9d90> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487f9f50> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e797150> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e797310> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e7974d0> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e797690> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e797850> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e797a10> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e797bd0> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e797d90> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e797f50> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e7b5150> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e7b5310> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e7b54d0> to <Neurons of <Ensemble "MSN ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e7b5690> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e7b5850> to <Neurons of <Ensemble "MSN ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e7b5a10> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e7b5bd0> to <Neurons of <Ensemble "MSN ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e7b5d50> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc83e7b5f10> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848797110> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848797310> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487974d0> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848797690> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848797810> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487979d0> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848797b90> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848797d50> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848797f10> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487b6110> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487b6310> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487b64d0> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487b6690> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487b6850> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487b6a10> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487b6bd0> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487b6d90> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487b6f50> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848755150> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848755310> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487554d0> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848755690> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848755850> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848755a10> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848755bd0> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848755d90> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848755f50> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848775150> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848775310> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487754d0> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848775690> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848775850> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848775a10> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848775bd0> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848775d90> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848775f50> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848715150> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848715310> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487154d0> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848715690> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848715850> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848715a10> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848715bd0> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848715d90> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848715f50> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848732150> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848732310> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848732510> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8487326d0> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848732850> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848732a10> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848732bd0> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848732d10> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848732f50> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8486d2150> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8486d2310> to <Neurons of <Ensemble "FSI ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8486d24d0> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8486d2690> to <Neurons of <Ensemble "FSI ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8486d2850> to <Neurons of <Ensemble "FSI ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# ...
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848549a90> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848549c50> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848549dd0> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848549f90> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848568190> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848568350> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848568510> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8485686d0> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848568890> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848568a50> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848568c10> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848568dd0> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848568f90> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848509190> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848509350> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848509510> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8485096d0> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848509890> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848509a50> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848509c10> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848509dd0> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848509f90> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848526190> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848526350> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848526490> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8485266d0> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848526890> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848526a50> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848526c10> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848526dd0> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848526f90> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484c6190> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484c6350> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484c6510> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484c66d0> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484c6890> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484c6a50> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484c6c10> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484c6dd0> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484c6f90> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484e4190> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484e4390> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484e4550> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484e4710> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# * GPi Inputs
# {'PTN': [<Ensemble "PTN ch0" at 0x7fc85f3b5710>, <Ensemble "PTN ch1" at 0x7fc85f3b5810>, <Ensemble "PTN ch2" at 0x7fc85f3b5910>], 'CSN': [<Ensemble "CSN ch0" at 0x7fc85f3b5510>, <Ensemble "CSN ch1" at 0x7fc85f3b5590>, <Ensemble "CSN ch2" at 0x7fc85f3b5610>], 'GPi': [<Ensemble "GPi ch0" at 0x7fc85f3b5050>, <Ensemble "GPi ch1" at 0x7fc85f3b5250>, <Ensemble "GPi ch2" at 0x7fc85f3b5350>], 'GPe': [<Ensemble "GPe ch0" at 0x7fc85f409b50>, <Ensemble "GPe ch1" at 0x7fc85f409d10>, <Ensemble "GPe ch2" at 0x7fc85f3b5090>], 'STN': [<Ensemble "STN ch0" at 0x7fc85f409cd0>, <Ensemble "STN ch1" at 0x7fc85f409ed0>, <Ensemble "STN ch2" at 0x7fc85f409bd0>], 'MSN': [<Ensemble "MSN ch0" at 0x7fc868a67410>, <Ensemble "MSN ch1" at 0x7fc874a99690>, <Ensemble "MSN ch2" at 0x7fc85f4094d0>], 'CMPf': [<Ensemble "CMPf ch0" at 0x7fc85f3b5a90>, <Ensemble "CMPf ch1" at 0x7fc85f3b5b90>, <Ensemble "CMPf ch2" at 0x7fc85f3b5c90>], 'FSI': [<Ensemble "FSI ch0" at 0x7fc85f409890>, <Ensemble "FSI ch1" at 0x7fc85f4095d0>, <Ensemble "FSI ch2" at 0x7fc85f409710>]}
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484e4910> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484e4ad0> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484e4d50> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484e4f50> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848481150> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc8484812d0> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848481410> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848481610> to <Neurons of <Ensemble "GPi ch0">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848481790> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848481990> to <Neurons of <Ensemble "GPi ch1">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848481b10> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)
# /usr/local/lib/python2.7/dist-packages/nengo/base.py:105: SyntaxWarning: Creating new attribute 'weight' on '<Connection from <Node (unlabeled) at 0x7fc848481cd0> to <Neurons of <Ensemble "GPi ch2">>>'. Did you mean to change an existing attribute?
#   SyntaxWarning)

# %%
with nengo_ocl.Simulator(model) as sim:
    sim.run(1./timescale)
# Out:
# /usr/local/lib/python2.7/dist-packages/nengo/neurons.py:381: RuntimeWarning: divide by zero encountered in log1p
#   1.0 / (gain * (intercepts - 1) - 1)))
# No context argument was provided to nengo_ocl.Simulator
# Calling pyopencl.create_some_context() for you now:
# Simulation finished in 0:01:06.

# %%
plt.figure()


plt.subplot(2, 1, 1)
plt.plot(sim.trange(), sim.data[input_actions].argmax(axis=1))
plt.ylim(-0.1, 2.1)
plt.xlabel('time [s]')
plt.title("Index of actual max value")

plt.show()

plt.plot(sim.trange(), sim.data[selected_action][:,0])
plt.xlabel('time [s]')
plt.title("Basal ganglia selected max value")

plt.show()


plt.plot(sim.trange(), sim.data[selected_action][:,1])
plt.xlabel('time [s]')
plt.title("Basal ganglia selected max value")

plt.show()


plt.plot(sim.trange(), sim.data[selected_action][:,2])
plt.xlabel('time [s]')
plt.title("Basal ganglia selected max value")

plt.show()

rasterplot(sim.trange(), sim.data[CSN[0]])
plt.xlabel('time [s]')
plt.title("CSN")

plt.show()


rasterplot(sim.trange(), sim.data[CSN[1]])
plt.xlabel('time [s]')
plt.title("CSN")

plt.show()


rasterplot(sim.trange(), sim.data[CSN[2]])
plt.xlabel('time [s]')
plt.title("CSN")

plt.show()

rasterplot(sim.trange(), sim.data[MSN[0]])
plt.xlabel('time [s]')
plt.title("MSN")

plt.show()


rasterplot(sim.trange(), sim.data[MSN[1]])
plt.xlabel('time [s]')
plt.title("MSN")

plt.show()


rasterplot(sim.trange(), sim.data[MSN[2]])
plt.xlabel('time [s]')
plt.title("MSN")

plt.show()

rasterplot(sim.trange(), sim.data[GPi[0]])
plt.xlabel('time [s]')
plt.title("GPi")

plt.show()


rasterplot(sim.trange(), sim.data[GPi[1]])
plt.xlabel('time [s]')
plt.title("GPi")

plt.show()


rasterplot(sim.trange(), sim.data[GPi[2]])
plt.xlabel('time [s]')
plt.title("GPi")

plt.show()
#plt.tight_layout()
